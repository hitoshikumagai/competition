# %% [markdown]
# <!-- <center><img src='https://www.nyrainc.com/assets/components/phpthumbof/cache/NYRA_Cares_810x430.d591d5ecfb0ffc5c0917ba2843346bc4.jpg'></center> -->
# <center><img src='https://storage.googleapis.com/kaggle-competitions/kaggle/37644/logos/header.png?t=2022-08-05-15-26-16'></center>
#
# <center><img src='https://cdn.dribbble.com/users/819689/screenshots/6176353/gallop.gif' width=800></center>
#
# <h1 style="color:#EE2737FF"><center><font size="+6">From "कैन्टर" - To - "गल्लोप"</font></center></h1>
#
# <h3 style="text-align: right;color:rgb(0, 103, 71);"><i>By: Kush Trivedi</i></h3>
#
# <h2 style="color:#EE2737FF">About Me</h2>
#
# Please, allow me to introduce myself I am **Kush Trivedi** I am a **self taught Machine Learning Engineer** and I am a highly motivated learner intrigued by all aspects of Big Data Analytics and I don't know much about the Derby so please pardon me in advance. However, my passion towards horse ridding draged me to participate here. Lastly, **I would love to hear you feedback** on my analysis and correct me if I am wrong at certain place. Thank you.
#
# <h2 style="color:#EE2737FF">Goal of the Competition</h2>
#
# The **goal** of this competition is to **analyze horse racing tactics**, **drafting strategies**, and **path efficiency**. You will develop a model using never-before-released coordinate data along with basic race information.
#
# Your work will help racing horse owners, trainers, and veterinarians better understand how equine performance and welfare fit together. With better data analysis, equine welfare could significantly improve.
#
# <h2 style="color:#EE2737FF">Context</h2>
#
# Injury prevention is a critical component in modern athletics. Sports that involve animals, such as horse racing, are no different than human sport. Typically, efficiency in movement correlates to both improvements in performance and injury prevention.
#
# A wealth of data is now collected, **including measures for heart rate**, **EKG**, **longitudinal movement**, **dorsal/ventral movement**, **medial/lateral deviation**, **total power** and **total landing vibration**. Your data science skills and analysis are needed to decipher what makes the most positive impact.
#
# In this competition, you will create **a model to interpret one aspect of this new data**. You’ll be among the first to access X/Y coordinate mapping of horses during races. Using the data, you might **analyze jockey decision making**, **compare race surfaces**, or **measure the relative importance of drafting**. With considerable data, contestants can flex their creativity problem solving skills.
#
# The New York Racing Association (NYRA) and the New York Thoroughbred Horsemen's Association (NYTHA) conduct world class thoroughbred racing at Aqueduct Racetrack, Belmont Park and Saratoga Race Course.
#
# With your help, NYRA and NYTHA will better understand their vast data set, which could lead to new ways of racing and training in a highly traditional industry. With improved use of horse tracking data, you could help improve equine welfare, performance and rider decision making.
#
# <h2 style="color:#EE2737FF">Anout Dataset</h2>
#
# `track_id` - 3 character id for the track the race took place at.
# > **AQU -Aqueduct**
#
# > **BEL - Belmont**
#
# > **SAR - Saratoga**
#
# `race_date` - date the race took place. **YYYY-MM-DD**.
#
# `race_number` - Number of the race. Passed as 3 characters but **can be cast or converted to int** for this data set.
#
# `program_number` - **Program number of the horse** in the race passed as 3 characters. Should remain 3 characters as it isn't limited to just numbers. Is essentially the **unique identifier of the horse** in the race.
#
# `trakus_index` - The common collection of point of the **lat / long** of the horse in the race passed as an integer. From what we can tell, it's collected **every 0.25 seconds**.
#
# `latitude` - The **latitude of the horse** in the race passed as a float.
#
# `longitude` - The **longitude of the horse** in the race passed as a float.
#
# `distance_id` - **Distance** of the race **in furlongs** passed as an integer.
# > - Example - **600** would be **6** furlongs.
#
# `course_type` - The course the race was run over passed as one character.
# > **M - Hurdle**
#
# > **D - Dirt**
#
# > **O - Outer turf**
#
# > **I - Inner turf**
#
# > **T - turf**
#
# `track_condition` - The condition of the course the race was run on passed as three characters.
# > **YL - Yielding**
#
# > **FM - Firm**
#
# > **SY - Sloppy**
#
# > **GD - Good**
#
# > **FT - Fast**
#
# > **MY - Muddy**
#
# > **SF - Soft**.
#
# `run_up_distance` - **Distance** in **feet** of the **gate to the start** of the race passed as an integer.
#
# `race_type` - The classification of the race passed as as five characters.
# > **STK - Stakes**
#
# > **WCL - Waiver Claiming**
#
# > **WMC - Waiver Maiden Claiming**
#
# > **SST - Starter Stakes**
#
# > **SHP - Starter Handicap**
#
# > **CLM - Claiming**
#
# > **STR - Starter Allowance**
#
# > **AOC - Allowance Optionl Claimer**
#
# > **SOC - Starter Optional Claimer**
#
# > **MCL - Maiden Claiming**
#
# > **ALW - Allowance**
#
# > **MSW - Maiden Special Weight**.
#
# `purse` - Purse in **US dollars** of the race passed as an money with two decimal places.
#
# `post_time` - **Time of day** the race began passed as 5 character.
# > Example - **01220** would be **12:20**.
#
# `weight_carried` - An integer of the **weight carried by the horse** in the race.
#
# `jockey` - **Name of the jockey** on the horse in the race. 50 character max.
#
# `odds` - Odds to win the race passed as an integer. **Divide by 100 to derive the odds to 1**.
# >  - Example - **1280** would be **12.8-1**.
#
# <h2 style="color:#EE2737FF">Sponsors</h2>
#
# **Thank you all for providing such a great opportunity. I really appreciate for this opprotunity.**
#
# <center><img src='https://i.postimg.cc/jSSW49JD/Untitled-drawio-removebg-preview.png', width=900></center>
#
# # <div style="color:#EE2737FF;display:fill;border-radius:5px;background-color:#28334AFF;letter-spacing:0.1px;overflow:hidden"><p style="padding:15px;color:#EE2737FF;overflow:hidden;margin:0;font-size:100%;text-align:center">Table of Contents</p></div>
#
# <h2 style="color:#EE2737FF">★ Does Race Depends on Jockey or Tactics? What's your opnion?</h2>
#
# * [Import Libraries](#1)
# * [Data Loading](#2)
# * [Data Cleaning and Wrangling](#3)
# * [Helper Functions](#4)
#     * [Universal Summary Function for Data Frames](#4)
#     * [Universal Downcasting Memory Usage for Data Frames](#4)
# * [Downcasting Memory Usage](#5)
# * [Basic Summary of Start, Race, Tracking and Complete Dataset](#6)
# * [Advance Visualization EDA for New York Racing Association (2019)](#7)
#     * [Race Track Inference](#7)
#     * [Inference of Most Race by Month](#7)
#     * [Race Course Type Inference](#7)
#     * [Inference of Race Track Conditions](#7)
#     * [Types of Race Inference](#7)
#     * [Inference of Current Top - 10 Jockey's](#7)
# * [Statistical Testing](#8)
#     * [In progress....](#7)
#
# <h2 style="color:#EE2737FF">★ Machine Learning</h2>
#
# * [Research In Progress....](#9)
#
#
# # <div style="color:#EE2737FF;display:fill;border-radius:5px;background-color:#28334AFF;letter-spacing:0.1px;overflow:hidden"><p style="padding:10px;color:#EE2737FF;overflow:hidden;margin:0;font-size:100%"><b id= '1'>1 |</b> Import Libraries</p></div>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import glob
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.graph_objects as go
import matplotlib.patches as patches
from plotly.subplots import make_subplots

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
plt.rcParams['figure.dpi'] = 150
plt.rcParams["figure.figsize"] = (10,5)
colors=sns.color_palette('Set3')
sns.set(rc={
    'axes.facecolor':'#FFFFFF', 
    'figure.facecolor':'#FFFFFF',
    'font.sans-serif':'Arial',
    'font.family':'sans-serif'
})
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# # <div style="color:#EE2737FF;display:fill;border-radius:5px;background-color:#28334AFF;letter-spacing:0.1px;overflow:hidden"><p style="padding:10px;color:#EE2737FF;overflow:hidden;margin:0;font-size:100%"><b id= '2'>2 |</b> Data Loading</p></div>

# %%
# Dataset by NYRA
start = pd.read_csv('../input/big-data-derby-2022/nyra_start_table.csv')
race = pd.read_csv('../input/big-data-derby-2022/nyra_race_table.csv')
tracking = pd.read_csv('../input/big-data-derby-2022/nyra_tracking_table.csv')
complete = pd.read_csv('../input/big-data-derby-2022/nyra_2019_complete.csv',low_memory=False)

# Top 10 Jockey 2022 by Kush Trivedi
dylan_davis = pd.read_csv('../input/jockey/Jockey/JockeyFile/DylanDavisFinal.csv')
flavien_prat = pd.read_csv('../input/jockey/Jockey/JockeyFile/FlavienPratFinal.csv')
irad_ortiz = pd.read_csv('../input/jockey/Jockey/JockeyFile/IradOrtizFinal.csv')
javier_castellano = pd.read_csv('../input/jockey/Jockey/JockeyFile/JavierCastellnoFinal.csv')
joel_rosario = pd.read_csv('../input/jockey/Jockey/JockeyFile/JoelRosarioFinal.csv')
john_r_velazquez = pd.read_csv('../input/jockey/Jockey/JockeyFile/JohnRVelazquezFinal.csv')
jose_l_ortiz = pd.read_csv('../input/jockey/Jockey/JockeyFile/JoseLOrtizFinal.csv')
luis_saez = pd.read_csv('../input/jockey/Jockey/JockeyFile/LuisSaezFinal.csv')
manuel_franco = pd.read_csv('../input/jockey/Jockey/JockeyFile/ManuelFrancoFinal.csv')
tyler_gaffalione = pd.read_csv('../input/jockey/Jockey/JockeyFile/TylerGaffalioneFinal.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/y8/7lrxsg1d77qddnpx9z8h9qz40000gn/T/ipykernel_17528/344062576.py in <module>
#       1 # Dataset by NYRA
# ----> 2 start = pd.read_csv('../input/big-data-derby-2022/nyra_start_table.csv')
#       3 race = pd.read_csv('../input/big-data-derby-2022/nyra_race_table.csv')
#       4 tracking = pd.read_csv('../input/big-data-derby-2022/nyra_tracking_table.csv')
#       5 complete = pd.read_csv('../input/big-data-derby-2022/nyra_2019_complete.csv',low_memory=False)
#
# NameError: name 'pd' is not defined

# %% [markdown]
# # <div style="color:#EE2737FF;display:fill;border-radius:5px;background-color:#28334AFF;letter-spacing:0.1px;overflow:hidden"><p style="padding:10px;color:#EE2737FF;overflow:hidden;margin:0;font-size:100%"><b id= '3'>3 |</b> Data Cleaning and Wrangling</p></div>

# %%
# Date Transformation
complete['race_date']  = pd.to_datetime(complete["race_date"], format='%Y-%m-%d')
complete['year'] = complete["race_date"].dt.year
complete['month'] = complete["race_date"].dt.month_name()
complete['day_name'] = complete["race_date"].dt.day_name()

# Distance Transformation
complete['furlongs'] = complete.distance_id / 100
complete.drop('distance_id', axis=1, inplace=True)

# Odds Transformation
complete['new_odds'] = complete['odds'] / 100
complete['new_odds'] = complete['new_odds'].apply(lambda x: round(x, 1))
complete['new_odds'] = complete['new_odds'].astype(str)
complete["new_odds"] = complete["new_odds"] + "-1"
complete.drop('odds', axis=1, inplace=True)
complete.rename(columns={'new_odds': 'odds'}, inplace=True)

# Post Time Transformation
def insert_colon(string, integer):
    return string[0:integer] + ':' + string[integer:]

complete['post_time'] = complete['post_time'].astype(str)
complete['post_time'] = complete['post_time'].apply(lambda x: insert_colon(x, -2))

# Jockey Transformation
dylan_davis_race_df = dylan_davis[['race_type','total']]
flavien_prat_race_df = flavien_prat[['race_type','total']]
irad_ortiz_race_df = irad_ortiz[['race_type','total']]
javier_castellano_race_df = javier_castellano[['race_type','total']]
joel_rosario_race_df = joel_rosario[['race_type','total']]
john_r_velazquez_race_df = john_r_velazquez[['race_type','total']]
jose_l_ortiz_race_df = jose_l_ortiz[['race_type','total']]
luis_saez_race_df = luis_saez[['race_type','total']]
manuel_franco_race_df = manuel_franco[['race_type','total']]
tyler_gaffalione_race_df = tyler_gaffalione[['race_type','total']]

# %% [markdown]
# # <div style="color:#EE2737FF;display:fill;border-radius:5px;background-color:#28334AFF;letter-spacing:0.1px;overflow:hidden"><p style="padding:10px;color:#EE2737FF;overflow:hidden;margin:0;font-size:100%"><b id= '4'>4 |</b> Helper Functions</p></div>
#
# 1. **Basic Summary Function**
# 2. **Downcast Memory Usage Function**

# %%
def basicSummary(dataFrameForSummary):
    print('\n\033[1;30;34mThis Datset consists of \033[0;0m\033[1m {}\033[0m \033[1;31;31mFeatures\033[0;0m & \033[1m{}\033[0m \033[1;31;32mSamples.\033[0;0m\n'.format(dataFrameForSummary.shape[1], dataFrameForSummary.shape[0]))
    summary = pd.DataFrame(dataFrameForSummary.dtypes, columns=['Data Type'])
    summary = summary.reset_index()
    summary = summary.rename(columns={'index': 'Feature'})
    summary['Num of Nulls'] = dataFrameForSummary.isnull().sum().values
    summary['Num of Unique'] = dataFrameForSummary.nunique().values
    summary['First Value'] = dataFrameForSummary.loc[0].values
    summary['Second Value'] = dataFrameForSummary.loc[1].values
    summary['Third Value'] = dataFrameForSummary.loc[2].values
    summary['Fourth Value'] = dataFrameForSummary.loc[3].values
    return summary

def downcastMemoryUsage(dataFrame):
    startMemoryOptimization = dataFrame.memory_usage().sum() / 1024 ** 2
    print('Memory usage of dataframe is: \033[1m{:.2f} MB\033[0m'.format(startMemoryOptimization))
    subTypeInt = ['uint8','uint16','uint32','uint64','int8','int16','int32','int64']
    subTypeFloat = ['float16','float32','float64']
    for column in dataFrame.columns:
        columnType = str(dataFrame[column].dtypes)
        maximumColumn = dataFrame[column].max()
        minimumColumn = dataFrame[column].min()
        if 'int' in columnType:
            for element in subTypeInt:
                if minimumColumn > np.iinfo(element).min and maximumColumn < np.iinfo(element).max:
                    dataFrame[column] = dataFrame[column].astype(element)
                    break
        elif 'float' in columnType:
            for element in subTypeFloat:
                if minimumColumn > np.finfo(element).min and maximumColumn < np.finfo(element).max:
                    dataFrame[column] = dataFrame[column].astype(element)
                    break
        elif 'object' in columnType:
            numberOfUnique = len(dataFrame[column].unique())
            numberOfTotal = len(dataFrame[column])
            if numberOfUnique / numberOfTotal < 0.5:
                dataFrame[column] = dataFrame[column].astype('category')
    endMemoryOptimization = dataFrame.memory_usage().sum() / 1024 ** 2
    print('Memory usage after optimization is: \033[1m{:.2f} MB\033[0m'.format(endMemoryOptimization))
    print('Compressed by: \033[1m{:.2f} %\033[0m'.format(100*(startMemoryOptimization - endMemoryOptimization) / startMemoryOptimization))
    return dataFrame

# %% [markdown]
# # <div style="color:#EE2737FF;display:fill;border-radius:5px;background-color:#28334AFF;letter-spacing:0.1px;overflow:hidden"><p style="padding:10px;color:#EE2737FF;overflow:hidden;margin:0;font-size:100%"><b id= '5'>5 |</b> Downcasting Memory Usage</p></div>

# %%
print("\033[1;30;34mStart Dataset Downcasting \033[0;0m")
start = downcastMemoryUsage(start)
print("\n\033[1;30;34mRace Dataset Downcasting \033[0;0m")
race = downcastMemoryUsage(race)
print("\n\033[1;30;34mTracking Dataset Downcasting \033[0;0m")
tracking = downcastMemoryUsage(tracking)
print("\n\033[1;30;34mComplete Dataset Downcasting \033[0;0m")
complete = downcastMemoryUsage(complete)

# %% [markdown]
# # <div style="color:#EE2737FF;display:fill;border-radius:5px;background-color:#28334AFF;letter-spacing:0.1px;overflow:hidden"><p style="padding:10px;color:#EE2737FF;overflow:hidden;margin:0;font-size:100%"><b id= '6'>6 |</b> Summary of Datasets</p></div>

# %%
# Start
fig = make_subplots(rows=1, cols=2)
fig.update_layout(
    title_text="<b>Start Dataset Summary</b>",
    title_x=0.5
)
fig['layout']['title']['font'] = dict(size=35, color='rgba(238, 39, 55, 1.00)')
fig.add_trace(go.Indicator(mode = "number", value = start.shape[0], number={'font':{'color': 'rgb(0, 103, 71)','size':100}}, title = {"text": "Rows (Samples)<br><span style='font-size:0.8em;color:rgb(0, 35, 156)'>In the Dataframe</span>"}, domain = {'x': [0, 0.5], 'y': [0.1, 1]}))
fig.add_trace(go.Indicator(mode = "number", value = start.shape[1], number={'font':{'color': 'rgb(0, 103, 71)','size':100}}, title = {"text": "Columns (Features)<br><span style='font-size:0.8em;color:rgb(0, 35, 156)'>In the Dataframe</span>"}, domain = {'x': [0.5, 1], 'y': [0, 0.4]}))
fig.show()
display(basicSummary(start))

# Race
fig = make_subplots(rows=1, cols=2)
fig.update_layout(
    title_text="<b>Race Dataset Summary</b>",
    title_x=0.5
)
fig['layout']['title']['font'] = dict(size=35, color='rgba(238, 39, 55, 1.00)')
fig.add_trace(go.Indicator(mode = "number", value = race.shape[0], number={'font':{'color': 'rgb(0, 103, 71)','size':100}}, title = {"text": "Rows (Samples)<br><span style='font-size:0.8em;color:rgb(0, 35, 156)'>In the Dataframe</span>"}, domain = {'x': [0, 0.5], 'y': [0.1, 1]}))
fig.add_trace(go.Indicator(mode = "number", value = race.shape[1], number={'font':{'color': 'rgb(0, 103, 71)','size':100}}, title = {"text": "Columns (Features)<br><span style='font-size:0.8em;color:rgb(0, 35, 156)'>In the Dataframe</span>"}, domain = {'x': [0.5, 1], 'y': [0, 0.4]}))
fig.show()
display(basicSummary(race))

# Tracking
fig = make_subplots(rows=1, cols=2)
fig.update_layout(
    title_text="<b>Tracking Dataset Summary</b>",
    title_x=0.5
)
fig['layout']['title']['font'] = dict(size=35, color='rgba(238, 39, 55, 1.00)')
fig.add_trace(go.Indicator(mode = "number", value = tracking.shape[0], number={'font':{'color': 'rgb(0, 103, 71)','size':100}}, title = {"text": "Rows (Samples)<br><span style='font-size:0.8em;color:rgb(0, 35, 156)'>In the Dataframe</span>"}, domain = {'x': [0, 0.5], 'y': [0.1, 1]}))
fig.add_trace(go.Indicator(mode = "number", value = tracking.shape[1], number={'font':{'color': 'rgb(0, 103, 71)','size':100}}, title = {"text": "Columns (Features)<br><span style='font-size:0.8em;color:rgb(0, 35, 156)'>In the Dataframe</span>"}, domain = {'x': [0.5, 1], 'y': [0, 0.4]}))
fig.show()
display(basicSummary(tracking))

# Complete
fig = make_subplots(rows=1, cols=2)
fig.update_layout(
    title_text="<b>Complete Dataset Summary</b>",
    title_x=0.5
)
fig['layout']['title']['font'] = dict(size=35, color='rgba(238, 39, 55, 1.00)')
fig.add_trace(go.Indicator(mode = "number", value = complete.shape[0], number={'font':{'color': 'rgb(0, 103, 71)','size':100}}, title = {"text": "Rows (Samples)<br><span style='font-size:0.8em;color:rgb(0, 35, 156)'>In the Dataframe</span>"}, domain = {'x': [0, 0.5], 'y': [0.1, 1]}))
fig.add_trace(go.Indicator(mode = "number", value = complete.shape[1], number={'font':{'color': 'rgb(0, 103, 71)','size':100}}, title = {"text": "Columns (Features)<br><span style='font-size:0.8em;color:rgb(0, 35, 156)'>In the Dataframe</span>"}, domain = {'x': [0.5, 1], 'y': [0, 0.4]}))
fig.show()
display(basicSummary(complete))

# %% [markdown]
# # <div style="color:#EE2737FF;display:fill;border-radius:5px;background-color:#28334AFF;letter-spacing:0.1px;overflow:hidden"><p style="padding:10px;color:#EE2737FF;overflow:hidden;margin:0;font-size:100%"><b id= '7'>7 |</b> Advanced EDA</p></div>
#
# <h2 style="color:#EE2737FF">New York Racing Association (2019) - Exploratory Data Analysis</h2>
#
# 1. >  **Racing Track Inference:-** It can be seen that the majority of the race were ran at **` AQU - Aqueduct `**, with **` BEL - Belmont `** coming in second and **` SAR - Saratoga `** at last.
#
# 2. > **Inference of Most Race by Month:-** The majority of the races are scheduled for the **` Fall `**, followed by the **` Summer`**, and **` Winter`**.
#
# 3. > **Race Course Type Inference:-** **80%** of time Race Course is either **` D- Dirt`** or **` T - Turf`** with dirt accounting for **62%** of the time.
#
# 4. > **Inference of Race Track Condition:-** Only **14%** of the time conditions are **` GD - Good`**, yet over **80%** of the race track is **FT - Fast`** and **FM - Firm`**.
# >> - This could be a **main feature to focus** for **Horse health**.
#
# 5. > **Types of Race Inference:-** **` CLM - Clamming`** is frequently the first of **12** different race categories, followed by **` MSW - Maiden Special Weight`** and **` MCL - Maiden Claiming`**.
# >> - **CLM - Claming** is a race in which **every horse** running **can be "Claimed"** or **purchased** after the race.
# >> - **MLW - Maiden Soecial Weight** is a highest caliber of maiden race in North America where all the **entrants carry a fixed amount of weight**.
# >>> * **Feature to note for speed and health of horse.**
# >> - **MCL - Maiden Claming** is a race for the **horses** that have **never won a race** and are **eligible to be claimed**.
#
# 6. > **Inference of Current Top-10 Jockeys:-** Although the jockey's **performances are nearly identical**, according to the [NYRA current jockey ranking](https://www.nyra.com/saratoga/leaders/jockeys/), I have examined the current entire dataset in another file and included a summary of it. However, there are a **few exceptions** **(**Marked as **'⚠️'** in table **)** or either the data is not full provided there can be some **data discrepancy** while providing it.
#
# <h3><center><b id='7'><span style='color:rgb(0, 103, 71);'><font size="+3">Table highlight's the Jockey's Amont of Race Starts in 2019</font></span> </b></center></h3>
#
# <style type="text/css">
#       table {
#         width: 100%;
#         padding: 0;
#         margin: 0;
#         border: 0;
#         border-collapse: collapse;
#       }
#
#       td {
#         width: 176px;
#         padding: 0 10px 0 0;
#         margin: 0;
#         border: 0;
#       }
#       td.last {
#         padding: 0;
#         margin: 0;
#         border: 0;
#       }
# </style>
#
# <font size="3">
#     <table style="border:1px solid black;">
#         <tr>
#             <td style="border:2px solid black;"><span style='color:rgb(0, 35, 156);'><center><b> Jockey </b></center></span></td>
#             <td style="border:2px solid black;"><span style='color:rgb(0, 35, 156);'><center><b>   ALW  </b></center></span></td>
#             <td style="border:2px solid black;"><span style='color:rgb(0, 35, 156);'><center><b>   AOC  </b></center></span></td>
#             <td style="border:2px solid black;"><span style='color:rgb(0, 35, 156);'><center><b>   CLM  </b></center></span></td>
#             <td style="border:2px solid black;"><span style='color:rgb(0, 35, 156);'><center><b>   MCL  </b></center></span></td>
#             <td style="border:2px solid black;"><span style='color:rgb(0, 35, 156);'><center><b>   MSW  </b></center></span></td>
#             <td style="border:2px solid black;"><span style='color:rgb(0, 35, 156);'><center><b>   SHP  </b></center></span></td>
#             <td style="border:2px solid black;"><span style='color:rgb(0, 35, 156);'><center><b>   SOC  </b></center></span></td>
#             <td style="border:2px solid black;"><span style='color:rgb(0, 35, 156);'><center><b>   SST  </b></center></span></td>
#             <td style="border:2px solid black;"><span style='color:rgb(0, 35, 156);'><center><b>   STK  </b></center></span></td>
#             <td style="border:2px solid black;"><span style='color:rgb(0, 35, 156);'><center><b>   STR  </b></center></span></td>
#             <td style="border:2px solid black;"><span style='color:rgb(0, 35, 156);'><center><b>   WCL  </b></center></span></td>
#             <td style="border:2px solid black;"><span style='color:rgb(0, 35, 156);'><center><b>   WMC  </b></center></span></td>
#         </tr>
#         <tr>
#             <td style="border-left:2px solid black;"><span style='color:#D34F73FF'><center><b>Irad Ortiz Jr</b></center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:black'><center>91</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:black'><center>113</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:black'><center>145</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:black'><center>94</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:#00B1D2FF'><center><b>177</b></center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:black'><center>-</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color: black'><center>5</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color: black'><center>-</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color: black'><center>139</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color: black'><center>33</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color: black'><center>4</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color: black'><center>1</center></span></td>
#         </tr>
#         <tr>
#             <td style="border-left:2px solid black;"><span style='color:#008C76FF'><center><b>Joel Rosario</b></center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:black'><center>59</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:black'><center>83</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:black'><center>112</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:black'><center>66</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:#00B1D2FF'><center><b>183</b></center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:black'><center>-</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color: black'><center>1</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color: black'><center>-</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color: black'><center>118</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color: black'><center>1</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color: black'><center>1</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color: black'><center>-</center></span></td>
#         </tr>
#         <tr>
#             <td style="border-left:2px solid black;"><span style='color:#E95C20FF'><center><b>Luis Saez</b></center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:black'><center>64</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:black'><center>74</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:black'><center>127</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:black'><center>93</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:#00B1D2FF'><center><b>161</b></center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:black'><center>-</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color: black'><center>3</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color: black'><center>-</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color: black'><center>105</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color: black'><center>33</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color: black'><center>5</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color: black'><center>1</center></span></td>
#         </tr>
#         <tr>
#             <td style="border-left:2px solid black;"><span style='color:#963CBDFF'><center><b>⚠️ Flavien Prat ⚠️</b></center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:black'><center>2</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:black'><center>1</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:black'><center>1</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:black'><center>1</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:black'><center>4</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:black'><center>-</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color: black'><center>-</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color: black'><center>-</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color: #00B1D2FF'><center><b>7</b></center></span></td>
#             <td style="border-left:2px solid black;"><span style='color: black'><center>-</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color: black'><center>-</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color: black'><center>-</center></span></td>
#         </tr>
#         <tr>
#             <td style="border-left:2px solid black;"><span style='color:#2C5F2DFF'><center><b>Javier Castellano</b></center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:black'><center>58</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:black'><center>67</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:black'><center>58</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:black'><center>44</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:#00B1D2FF'><center><b>169</b></center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:black'><center>-</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color: black'><center>2</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color: black'><center>-</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color: black'><center>119</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color: black'><center>23</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color: black'><center>1</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color: black'><center>-</center></span></td>
#         </tr>
#         <tr>
#             <td style="border-left:2px solid black;"><span style='color:#DAA03DFF'><center><b>Jose L. Ortiz</b></center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:black'><center>76</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:black'><center>99</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:black'><center>110</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:black'><center>65</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:#00B1D2FF'><center><b>190</b></center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:black'><center>-</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color: black'><center>1</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color: black'><center>-</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color: black'><center>129</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color: black'><center>30</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color: black'><center>2</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color: black'><center>-</center></span></td>
#         </tr>
#         <tr>
#             <td style="border-left:2px solid black;"><span style='color:#783937FF'><center><b>Manuel Franco</b></center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:black'><center>131</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:black'><center>144</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:#00B1D2FF'><center><b>285</b></center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:black'><center>208</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:black'><center>275</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:black'><center>2</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color: black'><center>17</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color: black'><center>-</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color: black'><center>151</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color: black'><center>53</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color: black'><center>7</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color: black'><center>1</center></span></td>
#         </tr>
#         <tr>
#             <td style="border-left:2px solid black;"><span style='color:#6E8898FF'><center><b>John R. Velazquez</b></center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:black'><center>55</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:black'><center>61</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:black'><center>22</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:black'><center>12</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:#00B1D2FF'><center><b>140</b></center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:black'><center>-</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color: black'><center>5</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color: black'><center>-</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color: black'><center>113</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color: black'><center>10</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color: black'><center>-</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color: black'><center>-</center></span></td>
#         </tr>
#         <tr>
#             <td style="border-left:2px solid black;"><span style='color:#A13941FF'><center><b>⚠️ Tyler Gaffalione ⚠️</b></center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:black'><center>14</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:black'><center>14</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:black'><center>29</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:black'><center>23</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:#00B1D2FF'><center><b>48</b></center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:black'><center>-</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color: black'><center>-</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color: black'><center>-</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color: black'><center>31</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color: black'><center>7</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color: black'><center>1</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color: black'><center>-</center></span></td>
#         </tr>
#         <tr>
#             <td style="border-left:2px solid black;"><span style='color:#28334AFF'><center><b>Dylan Davis</b></center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:black'><center>108</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:black'><center>115</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:#00B1D2FF'><center><b>284</b></center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:black'><center>198</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:black'><center>235</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color:black'><center>1</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color: black'><center>13</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color: black'><center>8</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color: black'><center>91</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color: black'><center>47</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color: black'><center>7</center></span></td>
#             <td style="border-left:2px solid black;"><span style='color: black'><center>1</center></span></td>
#         </tr>
#     </table>
# </font>
#
#
#  > We can assume by the data that **Javier Castellano** and **John R. Velazquez** have almost participated in same race category if we can have more data resource regarding winning place we can leverage odds value to predict it. Similarly, **Joel Rasario**, **Luis Saez** and **Jose L Ortiz** have same trend in particiaption in different race category. Lastly, **Manuel Franco** and **Dylan Davis** has participated in almost all race category so the data could be little bias so if we are preparing a model for race category we can **drop some of the feature** such as **SHP** , **SST** etc Also **we can prove that** the the **most of the data** is all about **CLM**, **MSW**, and **STK** from **type of race inference**. To **Note:** The Current Champion **Irad Ortiz Jr** has participated in almost every race with equally. It seems to me he has more experence in all type of race track conditions maybe that's why he is currently standing at [1st Place](https://www.nyra.com/saratoga/leaders/jockeys/). Needless, to say that I think that the there is some data discrepancy for **⚠️ Flavien Prat ⚠️** and **⚠️ Tyler Gaffalione ⚠️**.
#
# ### `To be continued` need to do more reasearch for preparing ML Models.

# %%
x=0
y=0
track_df = complete['track_id'].value_counts()
race_month_df = complete['month'].value_counts().sort_index(ascending=False).sort_values(ascending=False)
fig,axes = plt.subplots(1,2)
axes[0].pie(x= track_df, labels = track_df.index, colors=colors, autopct='%.0f%%',
            explode=[0.035 for i in track_df], startangle=10,
            wedgeprops={'linewidth': 2, 'edgecolor': 'k'},labeldistance=1.1)
axes[0].add_artist(plt.Circle((0, 0), 0.3, fc='#E4E6EB', ec='black', lw=2))
axes[0].annotate("Derby\nTracks", xy=(x, y),va="center",  ha="center")

axes[1].pie(x= race_month_df, labels = race_month_df.index, colors=colors, autopct='%.0f%%',
            explode=[0.1 for i in race_month_df], startangle=10,
            wedgeprops={'linewidth': 2, 'edgecolor': 'k'},labeldistance=1.1)
axes[1].add_artist(plt.Circle((0, 0), 0.35, fc='#E4E6EB', ec='black', lw=2))
axes[1].annotate("Derby\nMonths", xy=(x, y),va="center",  ha="center")

fig.suptitle("New York Racing Association (2019) - Exploratory Data Analysis", y=1)
plt.tight_layout(pad=1, w_pad=1, h_pad=1)
plt.show()


course_type_df = complete['course_type'].value_counts()
track_condition_df = complete['track_condition'].value_counts(normalize=True).mul(100).rename('percent').reset_index()
fig,axes = plt.subplots(1,2)
axes[0].pie(x= course_type_df, labels = course_type_df.index, colors=colors, autopct='%.0f%%',
            explode=[0.05 for i in course_type_df], startangle=165,
            wedgeprops={'linewidth': 2, 'edgecolor': 'k'},labeldistance=1.08, pctdistance=1.3)
axes[0].add_artist(plt.Circle((0, 0), 0.3, fc='#E4E6EB', ec='black', lw=2))
axes[0].annotate("Derby\nCourse", xy=(x, y),va="center",  ha="center")

axes[1]=sns.barplot(y="index", x= "percent",data=track_condition_df,order=track_condition_df['index'],edgecolor="black",palette=colors, hatch='/')
axes[1].set(xticklabels=[])
axes[1].set(ylabel=None, xlabel=None)
axes[1].set(title='Derby Race Track Conditions')

for p in axes[1].patches:
    value = f'{p.get_width():,.1f}%'
    x = p.get_x() + p.get_width() + 1.8
    y = p.get_y() + p.get_height() / 2 
    axes[1].text(x, y, value, ha='left', va='center', bbox=dict(facecolor='none', edgecolor='black', boxstyle='round', linewidth=1))

plt.tight_layout(pad=1, w_pad=1, h_pad=1)
plt.show()

race_type_df = complete['race_type'].value_counts(normalize=True).mul(100).rename('percent').reset_index()
r = sns.barplot(x="index", y= "percent",data=race_type_df,edgecolor="black",palette=colors, hatch='/')
r.set(yticklabels=[])
r.set(ylabel=None, xlabel=None)
r.set(title='Derby Race Types')
for p in r.patches:
    value = f'{p.get_height():,.1f}%'
    x = p.get_x() + 0.4
    y = p.get_height() + 0.9
    r.text(x, y, value, ha='center', bbox=dict(facecolor='none', edgecolor='black', boxstyle='round', linewidth=1))
plt.tight_layout(pad=1, w_pad=1, h_pad=1)
plt.show()

# 1
fig = plt.figure(figsize=(10,5))
ax = plt.subplot(122, polar=True)
plt.axis('off')

upperLimit = 145
lowerLimit = 33

max = irad_ortiz_race_df['total'].max()

slope = (max - lowerLimit) / max
heights = slope * irad_ortiz_race_df['total'] + lowerLimit

width = 2*np.pi / len(irad_ortiz_race_df.index)

indexes = list(range(1, len(irad_ortiz_race_df.index)+1))
angles = [element * width for element in indexes]

bars = ax.bar(
    x=angles, 
    height=heights, 
    width=width, 
    bottom=lowerLimit,
    linewidth=1, 
    edgecolor="black",
    color=colors
)

labelPadding = 10

for bar, angle, height, label in zip(bars,angles, heights, irad_ortiz_race_df["race_type"]):
    rotation = np.rad2deg(angle)
    alignment = ""
    if angle >= np.pi/2 and angle < 3*np.pi/2:
        alignment = "right"
        rotation = rotation + 180
    else: 
        alignment = "left"

    ax.text(
        x=angle, 
        y=lowerLimit + bar.get_height() + labelPadding, 
        s=label, 
        ha=alignment, 
        va='center', 
        rotation=rotation, 
        rotation_mode="anchor"
    ) 
    
for image_file_irad_ortiz_jr in glob.glob("../input/jockey/Jockey/JockeyImage/irad-ortiz-jr.png"):
    image_irad_ortiz_jr = plt.imread(image_file_irad_ortiz_jr)

ax = fig.add_subplot(121)
im = ax.imshow(image_irad_ortiz_jr)
patch = patches.Rectangle(xy=(0.6,8), width=500, height=510, transform=ax.transData)
im.set_clip_path(patch)
ax.axis('off')
fig.suptitle("Current Top - 10 Jockeys \n\n Irad Ortiz. Jr", y=1)
plt.show()


# 2
fig = plt.figure(figsize=(10,5))
ax = plt.subplot(121, polar=True)
plt.axis('off')

upperLimit = 285
lowerLimit = 60

max = joel_rosario_race_df['total'].max()

slope = (max - lowerLimit) / max
heights = slope * joel_rosario_race_df['total'] + lowerLimit

width = 2*np.pi / len(joel_rosario_race_df.index)

indexes = list(range(1, len(joel_rosario_race_df.index)+1))
angles = [element * width for element in indexes]

bars = ax.bar(
    x=angles, 
    height=heights, 
    width=width, 
    bottom=lowerLimit,
    linewidth=1, 
    edgecolor="black",
    color=colors
)

labelPadding = 10

for bar, angle, height, label in zip(bars,angles, heights, joel_rosario_race_df["race_type"]):
    rotation = np.rad2deg(angle)
    alignment = ""
    if angle >= np.pi/2 and angle < 3*np.pi/2:
        alignment = "right"
        rotation = rotation + 180
    else: 
        alignment = "left"

    ax.text(
        x=angle, 
        y=lowerLimit + bar.get_height() + labelPadding, 
        s=label, 
        ha=alignment, 
        va='center', 
        rotation=rotation, 
        rotation_mode="anchor"
    ) 
    
for image_file_joel_rosario in glob.glob("../input/jockey/Jockey/JockeyImage/joel-rosario.png"):
    image_joel_rosario = plt.imread(image_file_joel_rosario)

ax = fig.add_subplot(122)
im = ax.imshow(image_joel_rosario)
patch = patches.Rectangle(xy=(0.6,8), width=500, height=500, transform=ax.transData)
im.set_clip_path(patch)
ax.axis('off')
fig.suptitle("Joel Rosario", y=1)
plt.show()

# 3
fig = plt.figure(figsize=(10,5))
ax = plt.subplot(122, polar=True)
plt.axis('off')

upperLimit = 161
lowerLimit = 30

max = luis_saez_race_df['total'].max()

slope = (max - lowerLimit) / max
heights = slope * luis_saez_race_df['total'] + lowerLimit

width = 2*np.pi / len(luis_saez_race_df.index)

indexes = list(range(1, len(luis_saez_race_df.index)+1))
angles = [element * width for element in indexes]

bars = ax.bar(
    x=angles, 
    height=heights, 
    width=width, 
    bottom=lowerLimit,
    linewidth=1, 
    edgecolor="black",
    color=colors
)

labelPadding = 10

for bar, angle, height, label in zip(bars,angles, heights, luis_saez_race_df["race_type"]):
    rotation = np.rad2deg(angle)
    alignment = ""
    if angle >= np.pi/2 and angle < 3*np.pi/2:
        alignment = "right"
        rotation = rotation + 180
    else: 
        alignment = "left"

    ax.text(
        x=angle, 
        y=lowerLimit + bar.get_height() + labelPadding, 
        s=label, 
        ha=alignment, 
        va='center', 
        rotation=rotation, 
        rotation_mode="anchor"
    ) 
    
for image_file_luis_saez in glob.glob("../input/jockey/Jockey/JockeyImage/luis-saez.png"):
    image_luis_saez = plt.imread(image_file_luis_saez)

ax = fig.add_subplot(121)
im = ax.imshow(image_luis_saez)
patch = patches.Rectangle(xy=(0.6,8), width=400, height=500, transform=ax.transData)
im.set_clip_path(patch)
ax.axis('off')
fig.suptitle("Luis Saez", y=1)
plt.show()

# 4
fig = plt.figure(figsize=(10,5))
ax = plt.subplot(121, polar=True)
plt.axis('off')

upperLimit = 169
lowerLimit = 23

max = javier_castellano_race_df['total'].max()

slope = (max - lowerLimit) / max
heights = slope * javier_castellano_race_df['total'] + lowerLimit

width = 2*np.pi / len(javier_castellano_race_df.index)

indexes = list(range(1, len(javier_castellano_race_df.index)+1))
angles = [element * width for element in indexes]

bars = ax.bar(
    x=angles, 
    height=heights, 
    width=width, 
    bottom=lowerLimit,
    linewidth=1, 
    edgecolor="black",
    color=colors
)

labelPadding = 10

for bar, angle, height, label in zip(bars,angles, heights, javier_castellano_race_df["race_type"]):
    rotation = np.rad2deg(angle)
    alignment = ""
    if angle >= np.pi/2 and angle < 3*np.pi/2:
        alignment = "right"
        rotation = rotation + 180
    else: 
        alignment = "left"

    ax.text(
        x=angle, 
        y=lowerLimit + bar.get_height() + labelPadding, 
        s=label, 
        ha=alignment, 
        va='center', 
        rotation=rotation, 
        rotation_mode="anchor"
    ) 
    
for image_file_javier_castellano in glob.glob("../input/jockey/Jockey/JockeyImage/javier-castellano.png"):
    image_javier_castellano = plt.imread(image_file_javier_castellano)

ax = fig.add_subplot(122)
im = ax.imshow(image_javier_castellano)
patch = patches.Rectangle(xy=(0.6,8), width=500, height=500, transform=ax.transData)
im.set_clip_path(patch)
ax.axis('off')
fig.suptitle("Javier Castellano", y=1)
plt.show()

# 5
fig = plt.figure(figsize=(8,4))
ax = plt.subplot(122, polar=True)
plt.axis('off')

upperLimit = 7
lowerLimit = 1

max = flavien_prat_race_df['total'].max()

slope = (max - lowerLimit) / max
heights = slope * flavien_prat_race_df['total'] + lowerLimit

width = 2*np.pi / len(flavien_prat_race_df.index)

indexes = list(range(1, len(flavien_prat_race_df.index)+1))
angles = [element * width for element in indexes]

bars = ax.bar(
    x=angles, 
    height=heights, 
    width=width, 
    bottom=lowerLimit,
    linewidth=1, 
    edgecolor="black",
    color=colors
)

labelPadding = 1

for bar, angle, height, label in zip(bars,angles, heights, flavien_prat_race_df["race_type"]):
    rotation = np.rad2deg(angle)
    alignment = ""
    if angle >= np.pi/2 and angle < 3*np.pi/2:
        alignment = "right"
        rotation = rotation + 180
    else: 
        alignment = "left"

    ax.text(
        x=angle, 
        y=lowerLimit + bar.get_height() + labelPadding, 
        s=label, 
        ha=alignment, 
        va='center', 
        rotation=rotation, 
        rotation_mode="anchor"
    ) 
    
for image_file_flavien_prat in glob.glob("../input/jockey/Jockey/JockeyImage/flavien-prat.png"):
    image_flavien_prat = plt.imread(image_file_flavien_prat)

ax = fig.add_subplot(121)
im = ax.imshow(image_flavien_prat)
patch = patches.Rectangle(xy=(0.6,8), width=500, height=470, transform=ax.transData)
im.set_clip_path(patch)
ax.axis('off')
fig.suptitle("Flavien Prat", y=1)
plt.show()

# 6
fig = plt.figure(figsize=(10,5))
ax = plt.subplot(121, polar=True)
plt.axis('off')

upperLimit = 190
lowerLimit = 30

max = jose_l_ortiz_race_df['total'].max()

slope = (max - lowerLimit) / max
heights = slope * jose_l_ortiz_race_df['total'] + lowerLimit

width = 2*np.pi / len(jose_l_ortiz_race_df.index)

indexes = list(range(1, len(jose_l_ortiz_race_df.index)+1))
angles = [element * width for element in indexes]

bars = ax.bar(
    x=angles, 
    height=heights, 
    width=width, 
    bottom=lowerLimit,
    linewidth=1, 
    edgecolor="black",
    color=colors
)

labelPadding = 10

for bar, angle, height, label in zip(bars,angles, heights, jose_l_ortiz_race_df["race_type"]):
    rotation = np.rad2deg(angle)
    alignment = ""
    if angle >= np.pi/2 and angle < 3*np.pi/2:
        alignment = "right"
        rotation = rotation + 180
    else: 
        alignment = "left"

    ax.text(
        x=angle, 
        y=lowerLimit + bar.get_height() + labelPadding, 
        s=label, 
        ha=alignment, 
        va='center', 
        rotation=rotation, 
        rotation_mode="anchor"
    ) 
    
for image_file_jose_ortiz in glob.glob("../input/jockey/Jockey/JockeyImage/jose-ortiz.png"):
    image_jose_ortiz = plt.imread(image_file_jose_ortiz)

ax = fig.add_subplot(122)
im = ax.imshow(image_jose_ortiz)
patch = patches.Rectangle(xy=(0.6,8), width=500, height=500, transform=ax.transData)
im.set_clip_path(patch)
ax.axis('off')
fig.suptitle("Jose Ortiz", y=1)
plt.show()

# 7
fig = plt.figure(figsize=(10,5))
ax = plt.subplot(122, polar=True)
plt.axis('off')

upperLimit = 140
lowerLimit = 10

max = john_r_velazquez_race_df['total'].max()

slope = (max - lowerLimit) / max
heights = slope * john_r_velazquez_race_df['total'] + lowerLimit

width = 2*np.pi / len(john_r_velazquez_race_df.index)

indexes = list(range(1, len(john_r_velazquez_race_df.index)+1))
angles = [element * width for element in indexes]

bars = ax.bar(
    x=angles, 
    height=heights, 
    width=width, 
    bottom=lowerLimit,
    linewidth=1, 
    edgecolor="black",
    color=colors
)

labelPadding = 10

for bar, angle, height, label in zip(bars,angles, heights, john_r_velazquez_race_df["race_type"]):
    rotation = np.rad2deg(angle)
    alignment = ""
    if angle >= np.pi/2 and angle < 3*np.pi/2:
        alignment = "right"
        rotation = rotation + 180
    else: 
        alignment = "left"

    ax.text(
        x=angle, 
        y=lowerLimit + bar.get_height() + labelPadding, 
        s=label, 
        ha=alignment, 
        va='center', 
        rotation=rotation, 
        rotation_mode="anchor"
    ) 
    
for image_file_john_r_velazquez in glob.glob("../input/jockey/Jockey/JockeyImage/john-velazquez.png"):
    image_john_r_velazquez = plt.imread(image_file_john_r_velazquez)

ax = fig.add_subplot(121)
im = ax.imshow(image_john_r_velazquez)
patch = patches.Rectangle(xy=(0.6,8), width=1000, height=475, transform=ax.transData)
im.set_clip_path(patch)
ax.axis('off')
fig.suptitle("John Velazquez", y=1)
plt.show()

# 8
fig = plt.figure(figsize=(10,5))
ax = plt.subplot(121, polar=True)
plt.axis('off')

upperLimit = 285
lowerLimit = 60

max = manuel_franco_race_df['total'].max()

slope = (max - lowerLimit) / max
heights = slope * manuel_franco_race_df['total'] + lowerLimit

width = 2*np.pi / len(manuel_franco_race_df.index)

indexes = list(range(1, len(manuel_franco_race_df.index)+1))
angles = [element * width for element in indexes]

bars = ax.bar(
    x=angles, 
    height=heights, 
    width=width, 
    bottom=lowerLimit,
    linewidth=1, 
    edgecolor="black",
    color=colors
)

labelPadding = 10

for bar, angle, height, label in zip(bars,angles, heights, manuel_franco_race_df["race_type"]):
    rotation = np.rad2deg(angle)
    alignment = ""
    if angle >= np.pi/2 and angle < 3*np.pi/2:
        alignment = "right"
        rotation = rotation + 180
    else: 
        alignment = "left"

    ax.text(
        x=angle, 
        y=lowerLimit + bar.get_height() + labelPadding, 
        s=label, 
        ha=alignment, 
        va='center', 
        rotation=rotation, 
        rotation_mode="anchor"
    ) 
    
for image_file_manuel_franco in glob.glob("../input/jockey/Jockey/JockeyImage/manuel-franco.png"):
    image_manuel_franco = plt.imread(image_file_manuel_franco)

ax = fig.add_subplot(122)
im = ax.imshow(image_manuel_franco)
patch = patches.Rectangle(xy=(0.6,8), width=850, height=1000, transform=ax.transData)
im.set_clip_path(patch)
ax.axis('off')
fig.suptitle("Manuel Franco", y=1)
plt.show()

# 9
fig = plt.figure(figsize=(10,5))
ax = plt.subplot(122, polar=True)
plt.axis('off')

upperLimit = 235
lowerLimit = 50

max = dylan_davis_race_df['total'].max()

slope = (max - lowerLimit) / max
heights = slope * dylan_davis_race_df['total'] + lowerLimit

width = 2*np.pi / len(dylan_davis_race_df.index)

indexes = list(range(1, len(dylan_davis_race_df.index)+1))
angles = [element * width for element in indexes]

bars = ax.bar(
    x=angles, 
    height=heights, 
    width=width, 
    bottom=lowerLimit,
    linewidth=1, 
    edgecolor="black",
    color=colors
)

labelPadding = 10

for bar, angle, height, label in zip(bars,angles, heights, dylan_davis_race_df["race_type"]):
    rotation = np.rad2deg(angle)
    alignment = ""
    if angle >= np.pi/2 and angle < 3*np.pi/2:
        alignment = "right"
        rotation = rotation + 180
    else: 
        alignment = "left"

    ax.text(
        x=angle, 
        y=lowerLimit + bar.get_height() + labelPadding, 
        s=label, 
        ha=alignment, 
        va='center', 
        rotation=rotation, 
        rotation_mode="anchor"
    ) 
    
for image_file_dylan_davis in glob.glob("../input/jockey/Jockey/JockeyImage/dylan-davis.png"):
    image_dylan_davis = plt.imread(image_file_dylan_davis)

ax = fig.add_subplot(121)
im = ax.imshow(image_dylan_davis)
patch = patches.Rectangle(xy=(0.6,8), width=350, height=1000, transform=ax.transData)
im.set_clip_path(patch)
ax.axis('off')
fig.suptitle("Dylan Davis", y=1)
plt.show()

# 10
fig = plt.figure(figsize=(10,5))
ax = plt.subplot(121, polar=True)
plt.axis('off')

upperLimit = 48
lowerLimit = 7

max = tyler_gaffalione_race_df['total'].max()

slope = (max - lowerLimit) / max
heights = slope * tyler_gaffalione_race_df['total'] + lowerLimit

width = 2*np.pi / len(tyler_gaffalione_race_df.index)

indexes = list(range(1, len(tyler_gaffalione_race_df.index)+1))
angles = [element * width for element in indexes]

bars = ax.bar(
    x=angles, 
    height=heights, 
    width=width, 
    bottom=lowerLimit,
    linewidth=1, 
    edgecolor="black",
    color=colors
)

labelPadding = 10

for bar, angle, height, label in zip(bars,angles, heights, tyler_gaffalione_race_df["race_type"]):
    rotation = np.rad2deg(angle)
    alignment = ""
    if angle >= np.pi/2 and angle < 3*np.pi/2:
        alignment = "right"
        rotation = rotation + 180
    else: 
        alignment = "left"

    ax.text(
        x=angle, 
        y=lowerLimit + bar.get_height() + labelPadding, 
        s=label, 
        ha=alignment, 
        va='center', 
        rotation=rotation, 
        rotation_mode="anchor"
    ) 
    
for image_file_tyler_gaffalione in glob.glob("../input/jockey/Jockey/JockeyImage/tyler-gaffalione.png"):
    image_tyler_gaffalione = plt.imread(image_file_tyler_gaffalione)

ax = fig.add_subplot(122)
im = ax.imshow(image_tyler_gaffalione)
patch = patches.Rectangle(xy=(0.6,8), width=400, height=1000, transform=ax.transData)
im.set_clip_path(patch)
ax.axis('off')
fig.suptitle("Tyler Gaffalione", y=1)
plt.show()
